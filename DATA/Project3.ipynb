# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
df_b = basics
df_b.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes genres
# 0       0      1894      \N              1     \N
# 1       0      1892      \N              5     \N
# 2       0      1892      \N              4     \N
# 3       0      1892      \N             12     \N
# 4       0      1893      \N              1     \N

# %%
# replace missing values with NaN
df_b.replace({'\\N':np.nan}, inplace=True)

# %%
# Check for missing values 
df_b.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1245164
# endYear           9211067
# runtimeMinutes    6795228
# genres            9308649
# dtype: int64

# %%
# drop missing values from StartYear, Genres, runtimeMinutes
df_b = df_b.dropna(subset=['startYear', 'genres', 'runtimeMinutes'])

# %%
# check for dropna
df_b.isna().sum()
# Out:
# tconst            0.0
# titleType         0.0
# primaryTitle      0.0
# originalTitle     0.0
# isAdult           0.0
# startYear         0.0
# endYear           0.0
# runtimeMinutes    0.0
# genres            0.0
# dtype: float64

# %%
#Keep only titleType_movie & Keep startYear 2000-2022
keepTs_df= df_b[(df_b['startYear']>='2000') & (df_b['startYear']>='2022') & (df_b['titleType']=='movie')]
keepTs_df
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
# Exclude movies that are included in the documentary category.
is_documentary = keepTs_df['genres'].str.contains('Documentary',case=False)
df = keepTs_df[~is_documentary]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [156], line 2
#       1 # Exclude movies that are included in the documentary category.
# ----> 2 is_documentary = keepTs_df['genres'].str.contains('Documentary',case=False)
#       3 df = keepTs_df[~is_documentary]
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/strings/accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/strings/accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
new_df.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34792  tt0035423     movie                                     Kate & Leopold
# 61094  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67640  tt0069049     movie                         The Other Side of the Wind
# 77934  tt0079644     movie                                      November 1828
# 86770  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult startYear endYear  \
# 34792                             Kate & Leopold       0      2001     NaN
# 61094  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67640                 The Other Side of the Wind       0      2018     NaN
# 77934                              November 1828       0      2001     NaN
# 86770                          The Naked Monster       0      2005     NaN
#
#       runtimeMinutes                  genres
# 34792            118  Comedy,Fantasy,Romance
# 61094             70                   Drama
# 67640            122                   Drama
# 77934            140               Drama,War
# 86770            100    Comedy,Horror,Sci-Fi

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
df_akas = akas
df_akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = new_df['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34792      True
# 61094      True
# 67640      True
# 77934      True
# 86770      True
#            ...
# 9305772    True
# 9305781    True
# 9305820    True
# 9305865    True
# 9305949    True
# Name: tconst, Length: 144368, dtype: bool

# %%
#Filter basics
basics = new_df[keepers]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86770    tt0088751     movie
# ...            ...       ...
# 9305772  tt9916170     movie
# 9305781  tt9916190     movie
# 9305820  tt9916270     movie
# 9305865  tt9916362     movie
# 9305949  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86770                                    The Naked Monster
# ...                                                    ...
# 9305772                                      The Rehearsal
# 9305781                                          Safeguard
# 9305820                           Il talento del calabrone
# 9305865                                              Coven
# 9305949                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34792                               Kate & Leopold       0      2001     NaN
# 61094    El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67640                   The Other Side of the Wind       0      2018     NaN
# 77934                                November 1828       0      2001     NaN
# 86770                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9305772                                   O Ensaio       0      2019     NaN
# 9305781                                  Safeguard       0      2020     NaN
# 9305820                   Il talento del calabrone       0      2020     NaN
# 9305865                                   Akelarre       0      2020     NaN
# 9305949                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86770              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9305772             51                      Drama
# 9305781             95  Action,Adventure,Thriller
# 9305820             84                   Thriller
# 9305865             92              Drama,History
# 9305949            123                      Drama
#
# [143715 rows x 9 columns]

# %%
# replace missing values with NaN
basics.replace({'\\N':np.nan}, inplace=True)
# Out:
# /var/folders/z7/p9p_qw2d2nl80kxdth7151p40000gn/T/ipykernel_1453/4015043284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics.replace({'\\N':np.nan}, inplace=True)

# %%
ratings_url="https://datasets.imdbws.com/ratings.akas.tsv.gz"
ratings = pd.read_csv(akas_url, sep='\t', low_memory=False)
df_ratings = ratings
df_ratings.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers_ratings = new_df['tconst'].isin(ratings['titleId'])
keepers_ratings
# Out:
# 34792      True
# 61094      True
# 67640      True
# 77934      True
# 86770      True
#            ...
# 9305772    True
# 9305781    True
# 9305820    True
# 9305865    True
# 9305949    True
# Name: tconst, Length: 144368, dtype: bool

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['title.akas.tsv.gz', 'ratings.akas.tsv.gz', 'title_basics.csv.gz']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
## Save current dataframe to file.
akas.to_csv("Data/title.akas.tsv.gz", compression='gzip', index=False)

# %%
## Save current dataframe to file.
ratings.to_csv("Data/ratings.akas.tsv.gz", compression='gzip', index=False)
