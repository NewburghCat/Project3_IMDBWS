# %% [markdown]
# # # Project 3 _ Part 1

# %%
# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %% [markdown]
# # BASIC DATAFRAME

# %%
# 
## uploaded file 
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics['titleType'].value_counts()
# Out:
# tvEpisode       7104917
# short            901753
# movie            628502
# video            267907
# tvSeries         234839
# tvMovie          138461
# tvMiniSeries      46167
# tvSpecial         39288
# videoGame         32919
# tvShort           10760
# tvPilot               2
# Name: titleType, dtype: int64

# %%
# %%
# replace missing values with NaN
basics.replace({'\\N':np.nan}, inplace=True)

# %%
# %%
# get basic's dataframe info
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9405515 entries, 0 to 9405514
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 645.8+ MB

# %%
# 
# Check for missing values 
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1262586
# endYear           9306349
# runtimeMinutes    6767435
# genres             431198
# dtype: int64

# %%
###
# drop missing values from genres, runtimeMinutes

basics = basics.dropna(subset=['genres', 'runtimeMinutes'])

# %%
# check for missing values 
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear           98273
# endYear           2522452
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
basics = basics.loc[basics['titleType']=='movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9405280  tt9916362     movie
# 9405364  tt9916538     movie
# 9405405  tt9916622     movie
# 9405432  tt9916680     movie
# 9405465  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9405280                                              Coven
# 9405364                                Kuambil Lagi Hatiku
# 9405405        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9405432  De la ilusión al desconcierto: cine colombiano...
# 9405465                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9405280                                           Akelarre       0      2020
# 9405364                                Kuambil Lagi Hatiku       0      2019
# 9405405        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9405432  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9405465                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9405280     NaN             92               Drama,History
# 9405364     NaN            123                       Drama
# 9405405     NaN             57                 Documentary
# 9405432     NaN            100                 Documentary
# 9405465     NaN             49                 Documentary
#
# [372833 rows x 9 columns]

# %%
# Exclude movies that are included in the documentary category. 
is_documentary = basics['genres'].str.contains('Documentary', case=False)
df = basics[~is_documentary]

# %%
#convert startYear to float
df['startYear']= df['startYear'].astype(float)

#Keep only titleType_movie & Keep startYear 2000-2021
df = df[(df['startYear']>=2000) & (df['startYear']<=2021)]
df
# Out:
# /var/folders/z7/p9p_qw2d2nl80kxdth7151p40000gn/T/ipykernel_6569/3880904744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['startYear']= df['startYear'].astype(float)
#             tconst titleType  \
# 34793    tt0035423     movie
# 61095    tt0062336     movie
# 67643    tt0069049     movie
# 77937    tt0079644     movie
# 86773    tt0088751     movie
# ...            ...       ...
# 9405187  tt9916170     movie
# 9405196  tt9916190     movie
# 9405235  tt9916270     movie
# 9405280  tt9916362     movie
# 9405364  tt9916538     movie
#
#                                               primaryTitle  \
# 34793                                       Kate & Leopold
# 61095    The Tango of the Widower and Its Distorting Mi...
# 67643                           The Other Side of the Wind
# 77937                                        November 1828
# 86773                                    The Naked Monster
# ...                                                    ...
# 9405187                                      The Rehearsal
# 9405196                                          Safeguard
# 9405235                           Il talento del calabrone
# 9405280                                              Coven
# 9405364                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34793                               Kate & Leopold       0     2001.0     NaN
# 61095    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67643                   The Other Side of the Wind       0     2018.0     NaN
# 77937                                November 1828       0     2001.0     NaN
# 86773                            The Naked Monster       0     2005.0     NaN
# ...                                            ...     ...        ...     ...
# 9405187                                   O Ensaio       0     2019.0     NaN
# 9405196                                  Safeguard       0     2020.0     NaN
# 9405235                   Il talento del calabrone       0     2020.0     NaN
# 9405280                                   Akelarre       0     2020.0     NaN
# 9405364                        Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                     genres
# 34793              118     Comedy,Fantasy,Romance
# 61095               70                      Drama
# 67643              122                      Drama
# 77937              140                  Drama,War
# 86773              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9405187             51                      Drama
# 9405196             95  Action,Adventure,Thriller
# 9405235             84                   Thriller
# 9405280             92              Drama,History
# 9405364            123                      Drama
#
# [137297 rows x 9 columns]

# %% [markdown]
# # AKAS DATAFRAME / EDA

# %%
#
# Upload 2nd dataframe
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
df_akas = akas
df_akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# replace missing values with NaN
df_akas.replace({'\\N':np.nan}, inplace=True)

# %%
# US Filter 
df_filter_akas = df_akas[df_akas['region'] == 'US']
df_filter_akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 33999069  tt9916702         1  Loving London: The Playground     US      NaN
# 33999106  tt9916720        10                The Demonic Nun     US      NaN
# 33999108  tt9916720        12                      The Nun 2     US      NaN
# 33999126  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 33999142  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 33999069          NaN                    NaN               0
# 33999106           tv                    NaN               0
# 33999108  imdbDisplay                    NaN               0
# 33999126  imdbDisplay                    NaN               0
# 33999142  imdbDisplay                    NaN               0
#
# [1379579 rows x 8 columns]

# %% [markdown]
# # RATINGS DATAFRAME

# %%
#
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
df_ratings = ratings
df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1924
# 1  tt0000002            5.8       260
# 2  tt0000003            6.5      1736
# 3  tt0000004            5.6       175
# 4  tt0000005            6.2      2550

# %%
#
# replace missing values with NaN
df_ratings.replace({'\\N':np.nan}, inplace=True)

# %%
# Filter the ratings table down to only include the US by using the filter akas dataframe
keeper = df_ratings['tconst'].isin(df_filter_akas['titleId'])
keeper
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1251737    False
# 1251738     True
# 1251739    False
# 1251740    False
# 1251741    False
# Name: tconst, Length: 1251742, dtype: bool

# %%
# 
df_ratings_clean = df_ratings[keeper]
df_ratings_clean
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1924
# 1        tt0000002            5.8       260
# 4        tt0000005            6.2      2550
# 5        tt0000006            5.1       175
# 6        tt0000007            5.4       798
# ...            ...            ...       ...
# 1251716  tt9916204            8.2       250
# 1251722  tt9916348            8.5        17
# 1251723  tt9916362            6.4      5018
# 1251727  tt9916428            3.8        14
# 1251738  tt9916720            5.4       279
#
# [476963 rows x 3 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keeper1 = df['tconst'].isin(df_filter_akas['titleId'])
keeper1
# Out:
# 34793       True
# 61095       True
# 67643       True
# 77937      False
# 86773       True
#            ...
# 9405187     True
# 9405196     True
# 9405235    False
# 9405280     True
# 9405364    False
# Name: tconst, Length: 137297, dtype: bool

# %%
df = df[keeper1]
df
# Out:
#             tconst titleType  \
# 34793    tt0035423     movie
# 61095    tt0062336     movie
# 67643    tt0069049     movie
# 86773    tt0088751     movie
# 93909    tt0096056     movie
# ...            ...       ...
# 9404651  tt9914942     movie
# 9405047  tt9915872     movie
# 9405187  tt9916170     movie
# 9405196  tt9916190     movie
# 9405280  tt9916362     movie
#
#                                               primaryTitle  \
# 34793                                       Kate & Leopold
# 61095    The Tango of the Widower and Its Distorting Mi...
# 67643                           The Other Side of the Wind
# 86773                                    The Naked Monster
# 93909                                 Crime and Punishment
# ...                                                    ...
# 9404651                             Life Without Sara Amat
# 9405047                               The Last White Witch
# 9405187                                      The Rehearsal
# 9405196                                          Safeguard
# 9405280                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34793                               Kate & Leopold       0     2001.0     NaN
# 61095    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67643                   The Other Side of the Wind       0     2018.0     NaN
# 86773                            The Naked Monster       0     2005.0     NaN
# 93909                         Crime and Punishment       0     2002.0     NaN
# ...                                            ...     ...        ...     ...
# 9404651                 La vida sense la Sara Amat       0     2019.0     NaN
# 9405047                  My Girlfriend is a Wizard       0     2019.0     NaN
# 9405187                                   O Ensaio       0     2019.0     NaN
# 9405196                                  Safeguard       0     2020.0     NaN
# 9405280                                   Akelarre       0     2020.0     NaN
#
#         runtimeMinutes                     genres
# 34793              118     Comedy,Fantasy,Romance
# 61095               70                      Drama
# 67643              122                      Drama
# 86773              100       Comedy,Horror,Sci-Fi
# 93909              126                      Drama
# ...                ...                        ...
# 9404651             74                      Drama
# 9405047             97       Comedy,Drama,Fantasy
# 9405187             51                      Drama
# 9405196             95  Action,Adventure,Thriller
# 9405280             92              Drama,History
#
# [80036 rows x 9 columns]

# %%
# example making new folder with os
import os
os.makedirs('data/',exist_ok=True) 
# Confirm folder created
os.listdir("data/")
# Out:
# ['basics_clean_df.csv.gz',
#  'tmdb_api_results_[2000, 2001].json',
#  'ratings_clean_df.csv.gz',
#  'akas_clean_df.csv.gz',
#  'final_tmdb_data_[2000, 2001].csv.gz',
#  '.ipynb_checkpoints']

# %%
## Save current dataframe to file.
df.to_csv('data/basics_clean_df.csv.gz', compression='gzip', index=False)

# %%
## Save current dataframe to file. 
df_filter_akas.to_csv('data/akas_clean_df.csv.gz', compression='gzip', index=False)

# %%
## Save current dataframe to file.
df_ratings_clean.to_csv('data/ratings_clean_df.csv.gz', compression='gzip',  index=False)
