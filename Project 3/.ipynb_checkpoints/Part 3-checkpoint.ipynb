# %%
import pandas as pd
import os, time,json
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title.akas.tsv.gz',
#  'years_to_get.csv.gz',
#  'ratings.akas.tsv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'title_basics.csv.gz',
#  'tmdb_api_results_[2000, 2001].json',
#  'final_tmdb_data_[2000, 2001].csv.gz',
#  'ratings_cleaned.akas.tsv.gz',
#  "tmdb_api_results_['2000'].json"]

# %%
import json
with open('/Users/christinab/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['client-id', 'Api-key'])

# %%
#make a movie object using the .Movies function from tmdb
tmdb.API_Key = login['Api-key']

# %%
# list of tables needed for imports
# title_basics
# title_ratings
# title_genres
# genres
# tmdb_data

# %% [markdown]
# #### Table 1

# %%
#load dataframe from project part 1 as basics:
basics = pd.read_csv('Data/ratings_cleaned.akas.tsv.gz')
basics.head()
# Out:
#       tconst titleType                     primaryTitle  \
# 0  tt0119830     movie                      One Dog Day
# 1  tt0120589     movie             A Dangerous Practice
# 2  tt0200940     movie  Over-sexed Rugsuckers from Mars
# 3  tt0265705     movie                         Saurians
# 4  tt0283145     movie                     Wielka droga
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                      One Dog Day        0       2022      NaN
# 1             A Dangerous Practice        0       2022      NaN
# 2  Over-sexed Rugsuckers from Mars        0       2022      NaN
# 3                         Saurians        0       2022      NaN
# 4                     Wielka droga        0       2022      NaN
#
#    runtimeMinutes         genres
# 0             101  Action,Comedy
# 1             108          Drama
# 2              87  Comedy,Sci-Fi
# 3              83  Action,Sci-Fi
# 4              87      Drama,War

# %% [markdown]
# **List of Unique Genres**

# %%
# create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics.head(3)
# Out:
#       tconst titleType                     primaryTitle  \
# 0  tt0119830     movie                      One Dog Day
# 1  tt0120589     movie             A Dangerous Practice
# 2  tt0200940     movie  Over-sexed Rugsuckers from Mars
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                      One Dog Day        0       2022      NaN
# 1             A Dangerous Practice        0       2022      NaN
# 2  Over-sexed Rugsuckers from Mars        0       2022      NaN
#
#    runtimeMinutes         genres      genres_split
# 0             101  Action,Comedy  [Action, Comedy]
# 1             108          Drama           [Drama]
# 2              87  Comedy,Sci-Fi  [Comedy, Sci-Fi]

# %%
# separate the genres col- variables into there individual row 
exploded_genres = basics.explode('genres_split')
exploded_genres.head(2)
# Out:
#       tconst titleType primaryTitle originalTitle  isAdult  startYear  \
# 0  tt0119830     movie  One Dog Day   One Dog Day        0       2022
# 0  tt0119830     movie  One Dog Day   One Dog Day        0       2022
#
#    endYear  runtimeMinutes         genres genres_split
# 0      NaN             101  Action,Comedy       Action
# 0      NaN             101  Action,Comedy       Comedy

# %%
# Get the string column converted to a list of strings in each row
genres_split = basics['genres'].str.split(',')

## Explore the series using.explore() and take the .unique() entires only.
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Action', 'Comedy', 'Drama', 'Sci-Fi', 'War', 'Crime', 'Thriller',
#        'Horror', 'Mystery', 'Romance', 'Adventure', 'Animation',
#        'History', 'Biography', 'Family', 'Musical', 'Music', 'Fantasy',
#        'Western', 'Sport', 'Reality-TV', 'News', 'Talk-Show', 'Adult',
#        'Game-Show'], dtype=object)

# %%
# use the unique genres from the genres_split colummn 
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %% [markdown]
# **Create a new title table**

# %%
# create a new title_genres table with only the 'tconst & genres_split' columns
# save as a new df

title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0119830       Action
# 0  tt0119830       Comedy
# 1  tt0120589        Drama
# 2  tt0200940       Comedy
# 2  tt0200940       Sci-Fi

# %% [markdown]
# **Create a genre mapper dictionary to replace string genres with INT**

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# Make a dictionary with list of unique genres as the key and the new interger id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# make new interger genre_id and drop string genres
basics["genre_id"] = basics["genres"].map(genre_map)
basics = basics.drop(columns="genres")

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                            'Genre_ID': genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Table 2

# %%
# load ratings dataframe 

ratings = pd.read_csv('Data/ratings_cleaned.akas.tsv.gz')
ratings.head()
# Out:
#       tconst titleType                     primaryTitle  \
# 0  tt0119830     movie                      One Dog Day
# 1  tt0120589     movie             A Dangerous Practice
# 2  tt0200940     movie  Over-sexed Rugsuckers from Mars
# 3  tt0265705     movie                         Saurians
# 4  tt0283145     movie                     Wielka droga
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                      One Dog Day        0       2022      NaN
# 1             A Dangerous Practice        0       2022      NaN
# 2  Over-sexed Rugsuckers from Mars        0       2022      NaN
# 3                         Saurians        0       2022      NaN
# 4                     Wielka droga        0       2022      NaN
#
#    runtimeMinutes         genres
# 0             101  Action,Comedy
# 1             108          Drama
# 2              87  Comedy,Sci-Fi
# 3              83  Action,Sci-Fi
# 4              87      Drama,War

# %%
ratings['genres_splitr']= ratings['genres'].str.split(',')
ratings
# Out:
#          tconst titleType                     primaryTitle  \
# 0     tt0119830     movie                      One Dog Day
# 1     tt0120589     movie             A Dangerous Practice
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# 3     tt0265705     movie                         Saurians
# 4     tt0283145     movie                     Wielka droga
# ...         ...       ...                              ...
# 7435  tt9893130     movie        2025: Blood, White & Blue
# 7436  tt9893158     movie                         Clowning
# 7437  tt9893160     movie                       No Way Out
# 7438  tt9894000     movie    Twice As Strong: Made of Fire
# 7439  tt9904648     movie                     The Contrast
#
#                         originalTitle  isAdult  startYear  endYear  \
# 0                         One Dog Day        0       2022      NaN
# 1                A Dangerous Practice        0       2022      NaN
# 2     Over-sexed Rugsuckers from Mars        0       2022      NaN
# 3                            Saurians        0       2022      NaN
# 4                        Wielka droga        0       2022      NaN
# ...                               ...      ...        ...      ...
# 7435        2025: Blood, White & Blue        0       2022      NaN
# 7436                         Clowning        0       2022      NaN
# 7437                       No Way Out        0       2022      NaN
# 7438    Twice As Strong: Made of Fire        0       2022      NaN
# 7439                     The Contrast        0       2022      NaN
#
#       runtimeMinutes                 genres              genres_splitr
# 0                101          Action,Comedy           [Action, Comedy]
# 1                108                  Drama                    [Drama]
# 2                 87          Comedy,Sci-Fi           [Comedy, Sci-Fi]
# 3                 83          Action,Sci-Fi           [Action, Sci-Fi]
# 4                 87              Drama,War               [Drama, War]
# ...              ...                    ...                        ...
# 7435             120                 Comedy                   [Comedy]
# 7436              96          Crime,Romance           [Crime, Romance]
# 7437              89  Action,Crime,Thriller  [Action, Crime, Thriller]
# 7438             122                  Drama                    [Drama]
# 7439              82                 Comedy                   [Comedy]
#
# [7440 rows x 10 columns]

# %%
exploded_gr = ratings.explode('genres_splitr')
exploded_gr
# Out:
#          tconst titleType                     primaryTitle  \
# 0     tt0119830     movie                      One Dog Day
# 0     tt0119830     movie                      One Dog Day
# 1     tt0120589     movie             A Dangerous Practice
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# ...         ...       ...                              ...
# 7437  tt9893160     movie                       No Way Out
# 7437  tt9893160     movie                       No Way Out
# 7437  tt9893160     movie                       No Way Out
# 7438  tt9894000     movie    Twice As Strong: Made of Fire
# 7439  tt9904648     movie                     The Contrast
#
#                         originalTitle  isAdult  startYear  endYear  \
# 0                         One Dog Day        0       2022      NaN
# 0                         One Dog Day        0       2022      NaN
# 1                A Dangerous Practice        0       2022      NaN
# 2     Over-sexed Rugsuckers from Mars        0       2022      NaN
# 2     Over-sexed Rugsuckers from Mars        0       2022      NaN
# ...                               ...      ...        ...      ...
# 7437                       No Way Out        0       2022      NaN
# 7437                       No Way Out        0       2022      NaN
# 7437                       No Way Out        0       2022      NaN
# 7438    Twice As Strong: Made of Fire        0       2022      NaN
# 7439                     The Contrast        0       2022      NaN
#
#       runtimeMinutes                 genres genres_splitr
# 0                101          Action,Comedy        Action
# 0                101          Action,Comedy        Comedy
# 1                108                  Drama         Drama
# 2                 87          Comedy,Sci-Fi        Comedy
# 2                 87          Comedy,Sci-Fi        Sci-Fi
# ...              ...                    ...           ...
# 7437              89  Action,Crime,Thriller        Action
# 7437              89  Action,Crime,Thriller         Crime
# 7437              89  Action,Crime,Thriller      Thriller
# 7438             122                  Drama         Drama
# 7439              82                 Comedy        Comedy
#
# [12117 rows x 10 columns]

# %%
# Get the string column converted to a list of strings in each row
genres_sr = ratings['genres'].str.split(',')

## Explore the series using.explore() and take the .unique() entires only.
unique_gr = genres_sr.explode().unique()
unique_gr
# Out:
# array(['Action', 'Comedy', 'Drama', 'Sci-Fi', 'War', 'Crime', 'Thriller',
#        'Horror', 'Mystery', 'Romance', 'Adventure', 'Animation',
#        'History', 'Biography', 'Family', 'Musical', 'Music', 'Fantasy',
#        'Western', 'Sport', 'Reality-TV', 'News', 'Talk-Show', 'Adult',
#        'Game-Show'], dtype=object)

# %%
# save a list of unique genres 
unique_gr = sorted(exploded_gr['genres_splitr'].unique())

# %%
# Ratings table 

title_ratings = exploded_gr[['tconst', 'genres_splitr']]
title_ratings.head(3)
# Out:
#       tconst genres_splitr
# 0  tt0119830        Action
# 0  tt0119830        Comedy
# 1  tt0120589         Drama

# %%
# making the genre mapper dictionary 
genre_intsr= range(len(unique_gr))
genre_mapr = dict(zip(unique_gr, genre_ints))
genre_mapr
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# make a dictionary with list of unique genres as the key and the new interger id as values

genre_id_mapr = dict(zip(unique_gr, range(len(unique_gr))))
genre_id_mapr
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# make new interger genre_id and drop string genres
ratings["genre_id"] = ratings["genres"].map(genre_mapr)
ratings = ratings.drop(columns="genres")

# %%
# Manaually make dataframe with named cols from the .keys and .values
genre_lookupr = pd.DataFrame({'Genre_Name': genre_id_mapr.keys(),
                            'Genre_ID': genre_id_mapr.values()})
genre_lookupr.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Table 3

# %% [markdown]
# #### DataFrame to SQL

# %%
## loading mysql credentials 
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy_utils import create_database, database_exists

## Change username and password to match your personal MySQL Server settings
username = 'root' # default username for MySQL db is root
password = 'Ao9!#Gt8' # whatever password you chose during MySQL installation.

connection = f'mysql+pymysql://{username}:{password}@localhost/movies_yr'
engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies_yr)

# %%
if database_exists(connection):
    print('It exists!')
else:
    create_database(connection)
    print('Database created.')
# Out:
# It exists!

# %%
## Example 
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictionary using Sqlalchemy datatype objects
basics_schema = {
    'tconst': String(key_len+1),
    'primaryTitle': Text(title_len+1),
    'StartYear':Float(),
    'endYear':Float(),
    'runtimeMinutes': Integer()}

# %%
basics = basics.drop(columns=['genres_split'])

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7440 entries, 0 to 7439
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          7440 non-null   object
#  1   titleType       7440 non-null   object
#  2   primaryTitle    7440 non-null   object
#  3   originalTitle   7440 non-null   object
#  4   isAdult         7440 non-null   int64
#  5   startYear       7440 non-null   int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  7440 non-null   int64
#  8   genre_id        4254 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 523.2+ KB

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)
# Out:
# 7440

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7440 entries, 0 to 7439
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          7440 non-null   object
#  1   titleType       7440 non-null   object
#  2   primaryTitle    7440 non-null   object
#  3   originalTitle   7440 non-null   object
#  4   isAdult         7440 non-null   int64
#  5   startYear       7440 non-null   int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  7440 non-null   int64
#  8   genres_splitr   7440 non-null   object
#  9   genre_id        4254 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 581.4+ KB

# %%
ratings = ratings.drop(columns=['genres_splitr'])

# %%
## Example 
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = ratings['tconst'].fillna('').map(len).max()
title_len = ratings['primaryTitle'].fillna('').map(len).max()
## Create a schema dictionary using Sqlalchemy datatype objects
ratings_schema = {
    'tconst': String(key_len+1),
    'primaryTitle': Text(title_len+1),
    'StartYear':Float(),
    'endYear':Float(),
    'runtimeMinutes': Integer()}

# %%
# Save to sql with dtype and index=False
ratings.to_sql('title_ratings',engine,dtype=ratings_schema,if_exists='replace',index=False)
# Out:
# 7440

# %%
q= '''SHOW TABLES'''
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies_yr
# 0        title_basics
# 1       title_ratings

# %%
q= '''SELECT * FROM title_basics'''
pd.read_sql(q, engine)
# Out:
#          tconst titleType                     primaryTitle  \
# 0     tt0119830     movie                      One Dog Day
# 1     tt0120589     movie             A Dangerous Practice
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# 3     tt0265705     movie                         Saurians
# 4     tt0283145     movie                     Wielka droga
# ...         ...       ...                              ...
# 7435  tt9893130     movie        2025: Blood, White & Blue
# 7436  tt9893158     movie                         Clowning
# 7437  tt9893160     movie                       No Way Out
# 7438  tt9894000     movie    Twice As Strong: Made of Fire
# 7439  tt9904648     movie                     The Contrast
#
#                         originalTitle  isAdult  startYear endYear  \
# 0                         One Dog Day        0       2022    None
# 1                A Dangerous Practice        0       2022    None
# 2     Over-sexed Rugsuckers from Mars        0       2022    None
# 3                            Saurians        0       2022    None
# 4                        Wielka droga        0       2022    None
# ...                               ...      ...        ...     ...
# 7435        2025: Blood, White & Blue        0       2022    None
# 7436                         Clowning        0       2022    None
# 7437                       No Way Out        0       2022    None
# 7438    Twice As Strong: Made of Fire        0       2022    None
# 7439                     The Contrast        0       2022    None
#
#       runtimeMinutes  genre_id
# 0                101       NaN
# 1                108       7.0
# 2                 87       NaN
# 3                 83       NaN
# 4                 87       NaN
# ...              ...       ...
# 7435             120       5.0
# 7436              96       NaN
# 7437              89       NaN
# 7438             122       7.0
# 7439              82       5.0
#
# [7440 rows x 9 columns]

# %%
engine.execute("ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);")

# %%
q= '''SHOW TABLES'''
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies_yr
# 0        title_basics
# 1       title_ratings
