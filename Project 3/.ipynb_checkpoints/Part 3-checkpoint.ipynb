# %%
import pandas as pd
import os, time,json
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title.akas.tsv.gz',
#  'years_to_get.csv.gz',
#  'ratings.akas.tsv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'title_basics.csv.gz',
#  'tmdb_api_results_[2000, 2001].json',
#  'final_tmdb_data_[2000, 2001].csv.gz',
#  'ratings_cleaned.akas.tsv.gz',
#  "tmdb_api_results_['2000'].json"]

# %%
import json
with open('/Users/christinab/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['client-id', 'Api-key'])

# %%
#make a movie object using the .Movies function from tmdb
tmdb.API_Key = login['Api-key']

# %%
# list of tables needed for imports
# title_basics
# title_ratings
# title_genres
# genres
# tmdb_data

# %%
#load dataframe from project part 1 as basics:
basics = pd.read_csv('Data/ratings_cleaned.akas.tsv.gz')
basics.head()
# Out:
#       tconst titleType                     primaryTitle  \
# 0  tt0119830     movie                      One Dog Day
# 1  tt0120589     movie             A Dangerous Practice
# 2  tt0200940     movie  Over-sexed Rugsuckers from Mars
# 3  tt0265705     movie                         Saurians
# 4  tt0283145     movie                     Wielka droga
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                      One Dog Day        0       2022      NaN
# 1             A Dangerous Practice        0       2022      NaN
# 2  Over-sexed Rugsuckers from Mars        0       2022      NaN
# 3                         Saurians        0       2022      NaN
# 4                     Wielka droga        0       2022      NaN
#
#    runtimeMinutes         genres
# 0             101  Action,Comedy
# 1             108          Drama
# 2              87  Comedy,Sci-Fi
# 3              83  Action,Sci-Fi
# 4              87      Drama,War

# %% [markdown]
# **List of Unique Genres**

# %%
# create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics.head(3)
# Out:
#       tconst titleType                     primaryTitle  \
# 0  tt0119830     movie                      One Dog Day
# 1  tt0120589     movie             A Dangerous Practice
# 2  tt0200940     movie  Over-sexed Rugsuckers from Mars
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                      One Dog Day        0       2022      NaN
# 1             A Dangerous Practice        0       2022      NaN
# 2  Over-sexed Rugsuckers from Mars        0       2022      NaN
#
#    runtimeMinutes         genres      genres_split
# 0             101  Action,Comedy  [Action, Comedy]
# 1             108          Drama           [Drama]
# 2              87  Comedy,Sci-Fi  [Comedy, Sci-Fi]

# %%
# separate the genres col- variables into there individual row 
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#          tconst titleType                     primaryTitle  \
# 0     tt0119830     movie                      One Dog Day
# 0     tt0119830     movie                      One Dog Day
# 1     tt0120589     movie             A Dangerous Practice
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# 2     tt0200940     movie  Over-sexed Rugsuckers from Mars
# ...         ...       ...                              ...
# 7437  tt9893160     movie                       No Way Out
# 7437  tt9893160     movie                       No Way Out
# 7437  tt9893160     movie                       No Way Out
# 7438  tt9894000     movie    Twice As Strong: Made of Fire
# 7439  tt9904648     movie                     The Contrast
#
#                         originalTitle  isAdult  startYear  endYear  \
# 0                         One Dog Day        0       2022      NaN
# 0                         One Dog Day        0       2022      NaN
# 1                A Dangerous Practice        0       2022      NaN
# 2     Over-sexed Rugsuckers from Mars        0       2022      NaN
# 2     Over-sexed Rugsuckers from Mars        0       2022      NaN
# ...                               ...      ...        ...      ...
# 7437                       No Way Out        0       2022      NaN
# 7437                       No Way Out        0       2022      NaN
# 7437                       No Way Out        0       2022      NaN
# 7438    Twice As Strong: Made of Fire        0       2022      NaN
# 7439                     The Contrast        0       2022      NaN
#
#       runtimeMinutes                 genres genres_split
# 0                101          Action,Comedy       Action
# 0                101          Action,Comedy       Comedy
# 1                108                  Drama        Drama
# 2                 87          Comedy,Sci-Fi       Comedy
# 2                 87          Comedy,Sci-Fi       Sci-Fi
# ...              ...                    ...          ...
# 7437              89  Action,Crime,Thriller       Action
# 7437              89  Action,Crime,Thriller        Crime
# 7437              89  Action,Crime,Thriller     Thriller
# 7438             122                  Drama        Drama
# 7439              82                 Comedy       Comedy
#
# [12117 rows x 10 columns]

# %%
# Get the string column converted to a list of strings in each row
genres_split = basics['genres'].str.split(',')

## Explore the series using.explore() and take the .unique() entires only.
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Action', 'Comedy', 'Drama', 'Sci-Fi', 'War', 'Crime', 'Thriller',
#        'Horror', 'Mystery', 'Romance', 'Adventure', 'Animation',
#        'History', 'Biography', 'Family', 'Musical', 'Music', 'Fantasy',
#        'Western', 'Sport', 'Reality-TV', 'News', 'Talk-Show', 'Adult',
#        'Game-Show'], dtype=object)

# %%
# use the unique genres from the genres_split colummn 
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %% [markdown]
# **Create a new title table**

# %%
# create a new title_genres table with only the 'tconst & genres_split' columns
# save as a new df

title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0119830       Action
# 0  tt0119830       Comedy
# 1  tt0120589        Drama
# 2  tt0200940       Comedy
# 2  tt0200940       Sci-Fi

# %% [markdown]
# **Create a genre mapper dictionary to replace string genres with INT**

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# make new interger genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].map(genre_map)
# basics = basics.drop(columns='genres_split')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [20], line 2
#       1 # make new interger genre_id and drop string genres
# ----> 2 basics['genre_id'] = basics['genres_split'].map(genre_map)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/base.py:852, in IndexOpsMixin._map_values(self, mapper, na_action)
#     848     return cat.map(mapper)
#     850 values = self._values
# --> 852 indexer = mapper.index.get_indexer(values)
#     853 new_values = algorithms.take_nd(mapper._values, indexer)
#     855 return new_values
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3784, in Index.get_indexer(self, target, method, limit, tolerance)
#    3779     target = target.astype(dtype, copy=False)
#    3780     return this._get_indexer(
#    3781         target, method=method, limit=limit, tolerance=tolerance
#    3782     )
# -> 3784 return self._get_indexer(target, method, limit, tolerance)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3809, in Index._get_indexer(self, target, method, limit, tolerance)
#    3804         # error: "IndexEngine" has no attribute "_extract_level_codes"
#    3805         tgt_values = engine._extract_level_codes(  # type: ignore[attr-defined]
#    3806             target
#    3807         )
# -> 3809     indexer = self._engine.get_indexer(tgt_values)
#    3811 return ensure_platform_int(indexer)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/index.pyx:305, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas/_libs/hashtable_class_helper.pxi:5247, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'
